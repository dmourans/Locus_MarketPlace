# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("../data/processed/municipios_tratado.csv")

df_sp = df[df["codigo_uf"] == 35]
df_sp.head()
# Out:
#     ibge_code         municipio  latitude  longitude  capital  codigo_uf  \
# 30    3500105        Adamantina  -21.6820   -51.0737        0         35
# 32    3500204            Adolfo  -21.2325   -49.6451        0         35
# 62    3500303             Aguaí  -22.0572   -46.9735        0         35
# 65    3500402    Águas da Prata  -21.9319   -46.7176        0         35
# 67    3500501  Águas de Lindóia  -22.4733   -46.6314        0         35
#
#     siafi_id  ddd       fuso_horario
# 30      6101   18  America/Sao_Paulo
# 32      6103   17  America/Sao_Paulo
# 62      6105   19  America/Sao_Paulo
# 65      6107   19  America/Sao_Paulo
# 67      6109   19  America/Sao_Paulo

# %%
ddd_sp = (
    df_sp.groupby("ddd")["municipio"]
    .count()
    .reset_index()
)

ddd_sp
# Out:
#    ddd  municipio
# 0   11         64
# 1   12         38
# 2   13         22
# 3   14        100
# 4   15         49
# 5   16         74
# 6   17        117
# 7   18        108
# 8   19         73

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=ddd_sp,
    x="ddd",
    y="municipio"
)

plt.title("Quantidade de Municípios por DDD no Estado de São Paulo")
plt.xlabel("DDD")
plt.ylabel("Número de Municípios")

plt.show()
